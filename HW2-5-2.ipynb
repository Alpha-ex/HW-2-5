# %%
import pandas as pd

# Зчитування файлу CSV з вказанням параметра sep
dfs = pd.read_csv("2017_jun_final.csv")

# Виведення перших кількох рядків для перевірки
dfs.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
# Виведення розміру таблиці
print("Розмір таблиці:")
dfs.shape
# Out:
# Розмір таблиці:
# (8704, 25)

# %%
# Виведення типів стовпців
dfs.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# Порахунок пропущених значень у кожному стовпці
missing_values = dfs.isnull().sum()

# Визначення загальної кількості рядків у таблиці
total_rows = len(dfs)

# Порахунок частки пропусків у кожному стовпці
missing_ratio = missing_values / total_rows

# Виведення частки пропусків у кожному стовпці
print("Частка пропусків у кожному стовпці:")
missing_ratio
# Out:
# Частка пропусків у кожному стовпці:
# N                                   0.000000
# Посада                              0.000000
# Мова програмування                  0.442325
# Спеціалізація                       0.829389
# Загальний досвід роботи             0.000000
# Досвід роботи на поточному місці    0.000000
# Зарплата на місяць                  0.000000
# Зміна зарплати за 12 місяців        0.000000
# Місто                               0.000000
# Розмір компанії                     0.000000
# Тип компанії                        0.000000
# Стать                               0.000000
# Вік                                 0.000000
# Освіта                              0.000000
# Університет                         0.041131
# Ще студент                          0.000000
# Рівень англійської                  0.000000
# Предметна область                   0.025620
# Дата заповнення                     0.000000
# User.Agent                          0.000000
# ...

# %%
# Виберемо стовбець "Мова програмування"
columns_to_keep = ['Мова програмування']

# Використовуємо список для вибору потрібних стовпців
dfs_cleaned = dfs[columns_to_keep]

# Виведення перших кількох рядків очищеного DataFrame
dfs_cleaned.head()
# Out:
#   Мова програмування
# 0                NaN
# 1                NaN
# 2            C#/.NET
# 3         JavaScript
# 4         JavaScript

# %%
# Виведення першого рядка очищеного DataFrame, щоб перевірити наявність лише стовпця "Мова програмування"
dfs_cleaned.head(1)

# Порахунок пропущених значень у кожному стовпці
missing_values_cleaned = dfs_cleaned.isnull().sum()

# Визначення загальної кількості рядків у таблиці
total_rows_cleaned = len(dfs_cleaned)

# Порахунок частки пропусків у кожному стовпці
missing_ratio_cleaned = missing_values_cleaned / total_rows_cleaned

# Виведення частки пропусків у кожному стовпці
print("Частка пропусків у кожному стовпці після видалення:")
missing_ratio_cleaned
# Out:
# Частка пропусків у кожному стовпці після видалення:
# Мова програмування    0.442325
# dtype: float64

# %%
# Фільтрація рядків з мовою програмування Python
python_rows = dfs[dfs['Мова програмування'] == 'Python']

# Видалення рядків з пропусками, за винятком рядків з мовою програмування Python
dfs_cleaned = pd.concat([dfs.dropna(), python_rows])

# Виведення перших кількох рядків очищеного DataFrame
dfs_cleaned.head()
# Out:
#        N                    Посада Мова програмування Спеціалізація  \
# 12    13         Software Engineer             Python           NaN
# 68    69         Software Engineer             Python           NaN
# 87    88  Junior Software Engineer             Python           NaN
# 114  115  Junior Software Engineer             Python           NaN
# 143  144  Junior Software Engineer             Python           NaN
#
#     Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                        1                  менше 3 місяців
# 68                      1.5                              0.5
# 87                      0.5                              0.5
# 114                     1.5                              0.5
# 143                       1                                1
#
#      Зарплата на місяць  Зміна зарплати за 12 місяців Місто Розмір компанії  \
# 12                  800                           200  Київ      до 50 осіб
# ...

# %%
# Визначення розміру нової таблиці
cleaned_shape = dfs_cleaned.shape

# Виведення розміру нової таблиці
print("Розмір нової таблиці:")
cleaned_shape
# Out:
# Розмір нової таблиці:
# (207, 25)

# %%
# Фільтрація рядків, де мова програмування - Python
python_data = dfs[dfs['Мова програмування'] == 'Python']

# Виведення перших кількох рядків нової таблиці
python_data.head()
# Out:
#        N                    Посада Мова програмування Спеціалізація  \
# 12    13         Software Engineer             Python           NaN
# 68    69         Software Engineer             Python           NaN
# 87    88  Junior Software Engineer             Python           NaN
# 114  115  Junior Software Engineer             Python           NaN
# 143  144  Junior Software Engineer             Python           NaN
#
#     Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                        1                  менше 3 місяців
# 68                      1.5                              0.5
# 87                      0.5                              0.5
# 114                     1.5                              0.5
# 143                       1                                1
#
#      Зарплата на місяць  Зміна зарплати за 12 місяців Місто Розмір компанії  \
# 12                  800                           200  Київ      до 50 осіб
# ...

# %%
python_data_shape = python_data.shape

# Виведення розміру таблиці python_data
print("Розмір таблиці python_data:")
python_data_shape
# Out:
# Розмір таблиці python_data:
# (207, 25)

# %%
# Групування за стовпчиком "Посада"
grouped_data = dfs.groupby('Посада')

# Виведення перших кількох рядків з кожної групи
for position, group in grouped_data:
    print("Посада:", position)
group.head()
# Out:
# Посада: Business analyst
# Посада: DBA
# Посада: Data Scientist / Data Analyst
# Посада: Designer
# Посада: DevOps
# Посада: Director of Engineering / Program Director
# Посада: ERP / CRM
# Посада: Game designer
# Посада: HR
# Посада: HTML coder
# Посада: Junior QA engineer
# Посада: Junior Software Engineer
# Посада: Marketing
# Посада: Product Manager
# Посада: Project manager
# Посада: QA Tech Lead
# Посада: QA engineer
# Посада: Research Engineer
# Посада: Sales manager
# Посада: Scrum Master
# Посада: Security Specialist
# Посада: Senior Project Manager / Program Manager
# Посада: Senior QA engineer
# Посада: Senior Software Engineer
# Посада: Software Engineer
# Посада: Support
# Посада: Sysadmin
# Посада: System Architect
# Посада: Talent Researcher
# Посада: Team lead
# Посада: Technical Lead
# Посада: Technical writer
#          N            Посада Мова програмування Спеціалізація  \
# 187    188  Technical writer                NaN           NaN
# ...

# %%
# Виконання агрегації даних за стовпчиком "Посада" і знаходження мінімального та максимального значення у стовпчику "Зарплата на місяць"
aggregated_data = dfs.groupby('Посада')['Зарплата на місяць'].agg(['min', 'max'])

# Виведення агрегованих даних
aggregated_data
# Out:
#                                              min    max
# Посада
# Business analyst                             200   5000
# DBA                                          380   6000
# Data Scientist / Data Analyst                150   8000
# Designer                                     100   4000
# DevOps                                       194  10000
# Director of Engineering / Program Director  1500  34000
# ERP / CRM                                    100   6000
# Game designer                                150   6800
# HR                                           100   7000
# HTML coder                                   154   3000
# Junior QA engineer                            96   2000
# Junior Software Engineer                      75   2600
# Marketing                                    100   4000
# Product Manager                              250   5000
# Project manager                              190   8000
# QA Tech Lead                                 430   6000
# ...

# %%
def fill_avg_salary(row):
    # Перетворення значень рядка в числа
    row_numeric = pd.to_numeric(row, errors='coerce')
    avg_salary = row_numeric.mean(skipna=True)
    return avg_salary


# Створення нового стовпчика "avg" за допомогою методу apply та функції fill_avg_salary
dfs['avg'] = dfs.apply(fill_avg_salary, axis=1)

# Виведення перших кількох рядків DataFrame для перевірки
dfs.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
# Описова статистика для стовпчика "avg"
avg_salary_stats = dfs['avg'].describe()

# Виведення описової статистики
avg_salary_stats
# Out:
# count    8704.000000
# mean      830.742954
# std       392.654659
# min        68.944444
# 25%       553.050000
# 50%       805.250000
# 75%      1047.600000
# max      6865.200000
# Name: avg, dtype: float64

# %%
# Збереження таблиці у CSV файл
dfs.to_csv('output_data.csv', index=False)

print("Таблицю успішно збережено в файлі output_data.csv")
# Out:
# Таблицю успішно збережено в файлі output_data.csv

# %%
import matplotlib.pyplot as plt

plt.hist(dfs['Зарплата на місяць'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Зарплата на місяць')
plt.ylabel('Частота')
plt.title('Гістограма розподілу зарплат на місяць')
plt.show()

# %%
plt.scatter(dfs['Загальний досвід роботи'], dfs['Зарплата на місяць'], color='green')
plt.xlabel('Загальний досвід роботи')
plt.ylabel('Зарплата на місяць')
plt.title('Зв\'язок між загальним досвідом роботи та зарплатою на місяць')
plt.show()

# %%
avg_salary_by_city = dfs.groupby('Місто')['Зарплата на місяць'].mean()
avg_salary_by_city.plot(kind='bar', color='skyblue')
plt.xlabel('Місто')
plt.ylabel('Середня зарплата на місяць')
plt.title('Середня зарплата за містами')
plt.show()
